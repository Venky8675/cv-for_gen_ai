# %% [markdown]
# ### INTRODUCTIONS TO OPENCV & IMAGE PROCESSING

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img=cv2.imread(r"D:\DS_NIT\Oct'24\cv for gen_ai\ele1.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (240, 429, 3)

# %%
plt.imshow(img)

# %% [markdown]
# ##### MATPLOTLIB(R,G,B)
# ##### OPENCV CHANNEL (B,G,R)

# %%
img
# Out:
# array([[[ 70, 195, 223],
#         [ 77, 194, 221],
#         [ 82, 185, 210],
#         ...,
#         [ 59, 116, 161],
#         [ 37,  89, 130],
#         [ 23,  68, 105]],
#
#        [[ 86, 210, 240],
#         [ 84, 201, 228],
#         [ 83, 186, 213],
#         ...,
#         [ 50, 108, 150],
#         [ 34,  86, 126],
#         [ 24,  70, 104]],
#
#        [[ 93, 214, 246],
#         [ 85, 202, 231],
#         [ 82, 186, 215],
#         ...,
#         [ 41, 100, 139],
#         [ 24,  78, 113],
#         [ 34,  80, 111]],
#
#        ...,
#
#        [[ 63,  88,  90],
#         [ 62,  87,  89],
#         [ 64,  86,  91],
#         ...,
#         [ 27,  55,  66],
#         [ 27,  55,  66],
#         [ 27,  54,  68]],
#
#        [[ 80, 111, 114],
#         [ 83, 112, 116],
#         [ 86, 112, 118],
#         ...,
#         [ 23,  54,  63],
#         [ 23,  54,  63],
#         [ 24,  54,  65]],
#
#        [[ 88, 121, 124],
#         [ 91, 124, 127],
#         [ 95, 124, 129],
# ...

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
fix_img.shape
# Out:
# (240, 429, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
img_gray=cv2.imread(r"D:\DS_NIT\Oct'24\cv for gen_ai\ele1.jpg",cv2.IMREAD_GRAYSCALE)

# %%
img_gray
# Out:
# array([[189, 189, 181, ..., 123,  95,  74],
#        [205, 196, 182, ..., 114,  92,  75],
#        [210, 197, 183, ..., 105,  82,  84],
#        ...,
#        [ 86,  85,  85, ...,  55,  55,  55],
#        [108, 110, 111, ...,  53,  53,  54],
#        [118, 121, 122, ...,  49,  50,  50]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(img_gray,cmap='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (240, 429, 3)

# %%
fix_img_1=cv2.resize(fix_img,(120,215))

# %%
fix_img_1.shape
# Out:
# (215, 120, 3)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
fix_img_2=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[228, 200,  79],
#         [208, 182,  82],
#         [213, 182,  80],
#         ...,
#         [225, 182,  87],
#         [160, 114,  45],
#         [142, 100,  45]],
#
#        [[235, 203,  84],
#         [217, 187,  84],
#         [221, 192,  85],
#         ...,
#         [168, 123,  43],
#         [141,  98,  36],
#         [132,  96,  39]],
#
#        [[245, 209,  94],
#         [230, 199,  90],
#         [238, 212,  96],
#         ...,
#         [138,  96,  36],
#         [136,  95,  40],
#         [151, 117,  56]],
#
#        ...,
#
#        [[ 78,  72,  55],
#         [ 75,  69,  51],
#         [ 78,  69,  50],
#         ...,
#         [ 73,  58,  25],
#         [ 72,  57,  25],
#         [ 72,  56,  26]],
#
#        [[ 82,  80,  57],
#         [ 82,  77,  56],
#         [ 80,  73,  55],
#         ...,
#         [ 67,  55,  26],
#         [ 67,  55,  27],
#         [ 67,  55,  27]],
#
#        [[120, 117,  86],
#         [122, 116,  90],
#         [109, 101,  80],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3=cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_2,1)
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_2,2)
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3)
# Out:
# True

# %%
plt.imshow(img3)
